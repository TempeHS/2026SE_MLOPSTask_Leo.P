# %% [markdown]
# [Home](../../README.md)
#
# ### Model Training - Linear Regression
#
# Linear regression is an algorithm that provides a linear relationship between an independent variable and a dependent variable to predict the outcome of future events. We will now Train a Linear regression algorithm on the features you have engineered to see how closely we can predict the health outcomes for individuals.

# %% [markdown]
# #### Step 1
#
# Load the required dependencies:

# %%
# Import frameworks
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
plt.style.use('../../style_Matplotlib_charts.mplstyle')
from sklearn.linear_model import LinearRegression
import pickle

# %% [markdown]
# #### Step 2
#
# Store the data columns for Linear Regression.

# %%
# Create a data frame from the csv file
training_data = pd.read_csv('2.3.2.training_data.csv')

x_name = 'km_from_cbd'
y_name = 'price'
x = np.array(training_data[x_name]).reshape(-1, 1)
y = np.array(training_data[y_name])

# %% [markdown]
# #### Step 3
#
# Plot the feature `x` and target `y` data on a graph using the column headings as the graph labels.

# %%
# increasing graph size to view graph better
plt.figure(figsize=(12, 6))  
# Plot the data points
plt.scatter(x, y, marker='x', c='r', s=1)
# Set the title
plt.title("Property prices in relation to property distance from CBD")
# Set the y-axis label
plt.ylabel(f'Training {training_data[y_name].name}')
# Set the x-axis label
plt.xlabel(f'Training {training_data[x_name].name}')
plt.show()

# %% [markdown]
# #### Step 4
#
# Use the [Scikit-learn](https://scikit-learn.org/stable/) library to instantiate a Machine Learning model class and store it in the `my_model` variable as an object.

# %%
# Create the model
my_model = LinearRegression()
# Fit the model to the data
my_model.fit(x, y)
# Out:
# LinearRegression()

# %% [markdown]
# #### Step 5
#
# Plot the features, targets and model (linear regression).

# %%
y_pred = my_model.predict(x)
plt.figure(figsize=(12, 6))
plt.plot(x, y_pred)
plt.scatter(x, y, marker='x', c='r', s=1)
plt.title("Property prices in relation to property distance from CBD")
plt.ylabel(f'Training {training_data[y_name].name}')
plt.xlabel(f'Training {training_data[x_name].name}')
plt.show()

# %%
# save the model to disk
filename = 'my_saved_model_v1.sav'
pickle.dump(my_model, open('../2.4.Model_Testing_and_Validation/' + filename, 'wb'))

# %% [markdown]
# #### Step 6. Evaluate the correlation of each feature
# Students should perform single feature linear regression on each feature and evaluate the score of the model to get a feel for which features correlate with the target.

# %%
# Parking spaces
training_data = pd.read_csv("2.3.2.training_data.csv")

x_name = "num_parking"
y_name = "price"
x = np.array(training_data[x_name]).reshape(-1, 1)
y = np.array(training_data[y_name])

# %%
my_model = LinearRegression()
my_model.fit(x, y)
# Out:
# LinearRegression()

# %%
y_pred = my_model.predict(x)
plt.figure(figsize=(12, 6))
plt.plot(x, y_pred)
plt.scatter(x, y, marker="x", c="r", s=1)
plt.title("Property prices in relation to count of parking spaces on property")
plt.ylabel(f"Training {training_data[y_name].name}")
plt.xlabel(f"Training {training_data[x_name].name}")
plt.show()

# %%
# Property size
training_data = pd.read_csv("2.3.2.training_data.csv")

x_name = "property_size"
y_name = "price"
x = np.array(training_data[x_name]).reshape(-1, 1)
y = np.array(training_data[y_name])

# %%
my_model = LinearRegression()
my_model.fit(x, y)
# Out:
# LinearRegression()

# %%
y_pred = my_model.predict(x)
plt.figure(figsize=(12, 6))
plt.plot(x, y_pred)
plt.scatter(x, y, marker="x", c="r", s=1)
plt.title("Property prices in relation to property size")
plt.ylabel(f"Training {training_data[y_name].name}")
plt.xlabel(f"Training {training_data[x_name].name}")
plt.show()

# %%
# suburb population
training_data = pd.read_csv("2.3.2.training_data.csv")

x_name = "suburb_population"
y_name = "price"
x = np.array(training_data[x_name]).reshape(-1, 1)
y = np.array(training_data[y_name])

# %%
my_model = LinearRegression()
my_model.fit(x, y)
# Out:
# LinearRegression()

# %%
y_pred = my_model.predict(x)
plt.figure(figsize=(12, 6))
plt.plot(x, y_pred)
plt.scatter(x, y, marker="x", c="r", s=1)
plt.title("Property prices in relation to suburb population")
plt.ylabel(f"Training {training_data[y_name].name}")
plt.xlabel(f"Training {training_data[x_name].name}")
plt.show()

# %%
# suburb median income
training_data = pd.read_csv("2.3.2.training_data.csv")

x_name = "suburb_median_income"
y_name = "price"
x = np.array(training_data[x_name]).reshape(-1, 1)
y = np.array(training_data[y_name])

# %%
my_model = LinearRegression()
my_model.fit(x, y)
# Out:
# LinearRegression()

# %%
y_pred = my_model.predict(x)
plt.figure(figsize=(12, 6))
plt.plot(x, y_pred)
plt.scatter(x, y, marker="x", c="r", s=1)
plt.title("Property prices in relation to suburb median income")
plt.ylabel(f"Training {training_data[y_name].name}")
plt.xlabel(f"Training {training_data[x_name].name}")
plt.show()

# %%
# suburb sqkm
training_data = pd.read_csv("2.3.2.training_data.csv")

x_name = "suburb_sqkm"
y_name = "price"
x = np.array(training_data[x_name]).reshape(-1, 1)
y = np.array(training_data[y_name])

# %%
my_model = LinearRegression()
my_model.fit(x, y)
# Out:
# LinearRegression()

# %%
y_pred = my_model.predict(x)
plt.figure(figsize=(12, 6))
plt.plot(x, y_pred)
plt.scatter(x, y, marker="x", c="r", s=1)
plt.title("Property prices in relation to suburb area in square km")
plt.ylabel(f"Training {training_data[y_name].name}")
plt.xlabel(f"Training {training_data[x_name].name}")
plt.show()

# %%
# suburb elevation
training_data = pd.read_csv("2.3.2.training_data.csv")

x_name = "suburb_elevation"
y_name = "price"
x = np.array(training_data[x_name]).reshape(-1, 1)
y = np.array(training_data[y_name])

# %%
my_model = LinearRegression()
my_model.fit(x, y)
# Out:
# LinearRegression()

# %%
y_pred = my_model.predict(x)
plt.figure(figsize=(12, 6))
plt.plot(x, y_pred)
plt.scatter(x, y, marker="x", c="r", s=1)
plt.title("Property prices in relation to suburb elevation")
plt.ylabel(f"Training {training_data[y_name].name}")
plt.xlabel(f"Training {training_data[x_name].name}")
plt.show()

# %%
# km from cbd already done above

# %%
# num core rooms
training_data = pd.read_csv("2.3.2.training_data.csv")

x_name = "num_core_rooms"
y_name = "price"
x = np.array(training_data[x_name]).reshape(-1, 1)
y = np.array(training_data[y_name])

# %%
my_model = LinearRegression()
my_model.fit(x, y)
# Out:
# LinearRegression()

# %%
y_pred = my_model.predict(x)
plt.figure(figsize=(12, 6))
plt.plot(x, y_pred)
plt.scatter(x, y, marker="x", c="r", s=1)
plt.title("Property prices in relation to number of core rooms")
plt.ylabel(f"Training {training_data[y_name].name}")
plt.xlabel(f"Training {training_data[x_name].name}")
plt.show()

# %%
# suburb population density
training_data = pd.read_csv("2.3.2.training_data.csv")

x_name = "suburb_population_density"
y_name = "price"
x = np.array(training_data[x_name]).reshape(-1, 1)
y = np.array(training_data[y_name])

# %%
my_model = LinearRegression()
my_model.fit(x, y)
# Out:
# LinearRegression()

# %%
y_pred = my_model.predict(x)
plt.figure(figsize=(12, 6))
plt.plot(x, y_pred)
plt.scatter(x, y, marker="x", c="r", s=1)
plt.title("Property prices in relation to population density")
plt.ylabel(f"Training {training_data[y_name].name}")
plt.xlabel(f"Training {training_data[x_name].name}")
plt.show()

# %% [markdown]
# Now that we have looked at each feature it is easier to get a feel as to which features correlate the best to the target (price). This makes it easier to do __Multi-linear regression__.

# %% [markdown]
# #### Step 7. Multiple Variable Linear Regression
#
# You should be able to understand the code snippets with less guidelines.

# %%
# Create a data frame from the csv file
training_data = pd.read_csv('2.3.2.training_data.csv')

x_name = ['km_from_cbd','suburb_sqkm']
y_name = 'price'
x = np.array(training_data[x_name])
y = np.array(training_data[y_name])

# %%
# plot predictions and targets vs original features    
fig,ax=plt.subplots(1,len(x_name),figsize=(12,6),sharey=True)
for i in range(len(ax)):
    ax[i].scatter(x[:,i],y, label = 'price')
    ax[i].set_xlabel(x_name[i])
ax[0].set_ylabel("price"); ax[0].legend();
fig.suptitle("Property price")
plt.show()

# %%
# Create the model
my_model = LinearRegression()
# Fit the model to the data
my_model.fit(x, y)
# Out:
# LinearRegression()

# %%
# scatter plot predictions and targets vs original features    
y_pred = my_model.predict(x)
fig,ax=plt.subplots(1,len(x_name),figsize=(12,3),sharey=True)
for i in range(len(ax)):
    ax[i].scatter(x[:,i],y, label = 'price')
    ax[i].set_xlabel(x_name[i])
    ax[i].scatter(x[:,i],y_pred,color="orange", label = 'predict')
ax[0].set_ylabel("price"); ax[0].legend();
fig.suptitle("Property price")
plt.show()

# %%
# save the model to disk
filename = 'my_saved_model_v2.sav'
pickle.dump(my_model, open('../2.4.Model_Testing_and_Validation/' + filename, 'wb'))

# %% [markdown]
# #### Step 8. Explore differnet features
#
# Students should now use their acquired knowledge from step 6 to test and evaluate different feature combinations to produce a model with the best possible intuition.
